# %%
import xml.dom.minidom as xmlreader
import pandas as pd

doc = xmlreader.parse("export.osm")

print(doc.firstChild.tagName)
# Out:
# osm

# %%
actions = [] # keep only "modify"
old_or_new = []
street_id = []
street_name = []
maxspeed = []

# %%
acts = doc.getElementsByTagName("action")

for act in acts: 
    if act.getAttribute("type") != "modify": continue
    actions.append(act.getAttribute("type"))

ways = doc.getElementsByTagName("way")

for way in ways:
    street_id.append(way.getAttribute("id"))

oldnews = doc.getElementsByTagName("old")

# %%
import xml.etree.ElementTree as ET

tree = ET.parse('export.osm')
root = tree.getroot()

full_list = []
for act in root: # action, tag: action, attrib: type = "XX"
    for key, value in act.attrib.items(): 
        if value != "modify": continue
        actions.append(value) # all "modify"
        
        old_or_new = []
        for oldornew in act: # old & new
            street_id = []
            maxspeed = []
            street_name = []
            
            for way in oldornew: # way
                for key, value in way.attrib.items():
                    if key == "id": street_id.append(value)
                    for tags in way: # nd & tags
                        if "k" in tags.attrib.keys() and tags.attrib["k"] == 'maxspeed':            
                            maxspeed.append(tags.attrib["v"])
                        if "k" in tags.attrib.keys() and tags.attrib["k"] == 'name':            
                            street_name.append(tags.attrib["v"])
            if len(street_name) > 0:
                old_or_new.append({'id':street_id[0], 'tag':oldornew.tag, 'name':street_name[0], 'maxspeed':maxspeed[0]})
        if len(old_or_new) > 1:
            full_list.extend(old_or_new)
full_list
df = pd.DataFrame(full_list)
df
# Out:
#              id  tag                        name maxspeed
# 0       7039893  old                  IJburglaan       50
# 1       7039893  new                  IJburglaan       50
# 2       7039895  old                  IJburglaan       50
# 3       7039895  new                  IJburglaan       50
# 4       7039896  old                  IJburglaan       50
# ...         ...  ...                         ...      ...
# 3189  989756929  new               Nieuwe Hemweg       50
# 3190  989993502  old      2e Hugo de Grootstraat       50
# 3191  989993502  new  Tweede Hugo de Grootstraat       50
# 3192  990055230  old          Johan Huizingalaan       50
# 3193  990055230  new          Johan Huizingalaan       50
#
# [3194 rows x 4 columns]

# %%
#df = (df
#        .groupby('id').agg({})
#        .reset_index())
diff = df.pivot(index='id', columns='tag', values='maxspeed')
diff = diff[diff['new'] != diff['old']]
diff
# Out:
# tag       new old
# id
# 121282988  50  30
# 145235317  30  50
# 27542031   30  50
# 489971512  30  50
# 727447409  15  50
# 7377053    30  50
# 7377103    30  50
# 7377336    30  50
# 743742836  30  50
# 85389989   30  50
# 926546468  30  50
# 934779776  30  50
# 934779795  30  50

# %%
print(len(street_id))
print(len(actions))
print(len(old_or_new))
print(len(maxspeed))
print(len(street_name))
# Out:
# 11854
# 7898
# 7898
# 20556
# 19260

# %%
print(maxspeed)
# Out:
# ['50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '60', '60', '60', '60', '60', '60', '60', '60', '60', '60', '60', '60', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '50', '50', '50', '50', '50', '50', '50', '50', '50', '50', '
# ...

# %%
# import pandas as pd

# df = pd.DataFrame({'street_id':street_id, 
#                    'street_name':street_name, 
#                    'actions':actions, 
#                    'status':old_or_new, 
#                    'max_speed':maxspeed})

# df

# %%
old_or_new
# Out:
# ['old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
#  'old',
#  'new',
# ...
